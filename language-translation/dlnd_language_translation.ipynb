# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_id_text = [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split("\n")]
    target_id_text = [[target_vocab_to_int[word] for word in line.split()]+[target_vocab_to_int['<EOS>']] for line in target_text.split("\n")]
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    target = tf.placeholder(tf.int32, [None, None], name='target')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return (input, target, learning_rate, keep_prob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    go_id = tf.constant(target_vocab_to_int['<GO>'], shape=(batch_size, 1),dtype=tf.int32)
#     print(target_data)
    input_proce = tf.concat([go_id,target_data[:,:-1]],1)
    return input_proce

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
#     go放到处理input 的最前面，input的shape为batch, time_step,所以每个batch，只取列表的前-1个，添加go_id,在第二纬上面连接2个矩阵

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %% [markdown]
#     encoding_embedding_size

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)

    outputs, final_state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype=tf.float32)
    return final_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    step1 = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    outputs, final_state, final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, step1, 
                                                                                       dec_embed_input, sequence_length, 
                                                                                       scope=decoding_scope)
    
    train_logit = output_fn(outputs)
    train_logit = tf.nn.dropout(train_logit, keep_prob)
    
    return train_logit


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %%
# tf.contrib.seq2seq.simple_decoder_fn_train?

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %% [markdown]
#     tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, num_decoder_symbols, dtype=tf.int32, name=None)

# %%
# tf.contrib.seq2seq.simple_decoder_fn_inference?
# tf.contrib.seq2seq.dynamic_rnn_decoder?

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    dec_fn_infer = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, 
                                                                  encoder_state, 
                                                                  dec_embeddings, 
                                                                  start_of_sequence_id, 
                                                                  end_of_sequence_id, 
                                                                  maximum_length, 
                                                                  vocab_size)
    
    dropouted = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
#     Signature: tf.contrib.seq2seq.dynamic_rnn_decoder(cell, decoder_fn, inputs=None, 
#                                                        sequence_length=None, parallel_iterations=None, 
#                                                        swap_memory=False, time_major=False, scope=None, name=None)
    infer_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dropouted, dec_fn_infer, 
                                                                sequence_length=maximum_length, 
                                                                scope=decoding_scope)
    
    return infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
#     为什么为什么为什么

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
# -------------------------------------------------------------------------------------------------------
# - Implement decoding_layer() to create a Decoder RNN layer.
# - Create RNN cell for decoding using rnn_size and num_layers.
# - Create the output fuction using lambda to transform it's input, logits, to class logits.
# - Use the your decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob) function to get the training logits.
# - Use your decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob) function to get the inference logits.
#
# - Note: You'll need to use tf.variable_scope to share variables between training and inference.
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %% [markdown]
#     def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
#                          output_fn, keep_prob):

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    
    output_fn = lambda x: tf.layers.dense(x, vocab_size, activation=None, )
    
#     def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
#                          output_fn, keep_prob):
    with tf.variable_scope('decoding_layer') as decoding_scope:
        train_logit = decoding_layer_train(encoder_state, cell, dec_embed_input, sequence_length, decoding_scope,
                                           output_fn, keep_prob)
    
    
#     def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, 
#                              maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    maximum_length = max([len(line) for line in source_int_text])
#     print(maximum_length)
    with tf.variable_scope('decoding_layer', reuse=True) as decoding_scope:
        infer_logit = decoding_layer_infer(encoder_state, cell, dec_embeddings, 
                                           target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], maximum_length, 
                                           vocab_size, decoding_scope,output_fn, keep_prob)
    
    
    return (train_logit, infer_logit)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_input_data = tf.contrib.layers.embed_sequence(input_data, enc_embedding_size, source_vocab_size)
    enc_state = encoding_layer(enc_input_data, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
#     dec_embed_input = tf.contrib.layers.embed_sequence(dec_input, dec_embedding_size, target_vocab_size)
    dec_embeddings = tf.Variable(tf.random_uniform((target_vocab_size, dec_embedding_size), -1, 1))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
# def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
#                    num_layers, target_vocab_to_int, keep_prob):
    
    training_logits, inference_logits = decoding_layer(dec_embed_input, dec_embeddings, enc_state, 
                                                       target_vocab_size, sequence_length, rnn_size, num_layers, 
                                                       target_vocab_to_int, keep_prob)
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 20
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 5e-5
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/1077 - Train Accuracy:  0.140, Validation Accuracy:  0.177, Loss:  5.879
# Epoch   0 Batch    1/1077 - Train Accuracy:  0.104, Validation Accuracy:  0.178, Loss:  5.877
# Epoch   0 Batch    2/1077 - Train Accuracy:  0.053, Validation Accuracy:  0.178, Loss:  5.874
# Epoch   0 Batch    3/1077 - Train Accuracy:  0.099, Validation Accuracy:  0.179, Loss:  5.870
# Epoch   0 Batch    4/1077 - Train Accuracy:  0.097, Validation Accuracy:  0.178, Loss:  5.868
# Epoch   0 Batch    5/1077 - Train Accuracy:  0.100, Validation Accuracy:  0.178, Loss:  5.861
# Epoch   0 Batch    6/1077 - Train Accuracy:  0.097, Validation Accuracy:  0.178, Loss:  5.858
# Epoch   0 Batch    7/1077 - Train Accuracy:  0.093, Validation Accuracy:  0.177, Loss:  5.854
# Epoch   0 Batch    8/1077 - Train Accuracy:  0.095, Validation Accuracy:  0.177, Loss:  5.855
# Epoch   0 Batch    9/1077 - Train Accuracy:  0.102, Validation Accuracy:  0.178, Loss:  5.849
# Epoch   0 Batch   10/1077 - Train Accuracy:  0.059, Validation Accuracy:  0.178, Loss:  5.850
# Epoch   0 Batch   11/1077 - Train Accuracy:  0.143, Validation Accuracy:  0.177, Loss:  5.840
# Epoch   0 Batch   12/1077 - Train Accuracy:  0.100, Validation Accuracy:  0.178, Loss:  5.837
# Epoch   0 Batch   13/1077 - Train Accuracy:  0.142, Validation Accuracy:  0.177, Loss:  5.831
# Epoch   0 Batch   14/1077 - Train Accuracy:  0.148, Validation Accuracy:  0.176, Loss:  5.827
# Epoch   0 Batch   15/1077 - Train Accuracy:  0.099, Validation Accuracy:  0.177, Loss:  5.826
# Epoch   0 Batch   16/1077 - Train Accuracy:  0.104, Validation Accuracy:  0.176, Loss:  5.815
# Epoch   0 Batch   17/1077 - Train Accuracy:  0.101, Validation Accuracy:  0.176, Loss:  5.813
# Epoch   0 Batch   18/1077 - Train Accuracy:  0.100, Validation Accuracy:  0.178, Loss:  5.817
# Epoch   0 Batch   19/1077 - Train Accuracy:  0.100, Validation Accuracy:  0.180, Loss:  5.808
# Epoch   0 Batch   20/1077 - Train Accuracy:  0.102, Validation Accuracy:  0.179, Loss:  5.818
# Epoch   0 Batch   21/1077 - Train Accuracy:  0.113, Validation Accuracy:  0.185, Loss:  5.816
# Epoch   0 Batch   22/1077 - Train Accuracy:  0.103, Validation Accuracy:  0.186, Loss:  5.802
# Epoch   0 Batch   23/1077 - Train Accuracy:  0.112, Validation Accuracy:  0.190, Loss:  5.799
# Epoch   0 Batch   24/1077 - Train Accuracy:  0.115, Validation Accuracy:  0.191, Loss:  5.792
# Epoch   0 Batch   25/1077 - Train Accuracy:  0.119, Validation Accuracy:  0.191, Loss:  5.787
# Epoch   0 Batch   26/1077 - Train Accuracy:  0.119, Validation Accuracy:  0.200, Loss:  5.802
# Epoch   0 Batch   27/1077 - Train Accuracy:  0.175, Validation Accuracy:  0.207, Loss:  5.756
# Epoch   0 Batch   28/1077 - Train Accuracy:  0.161, Validation Accuracy:  0.229, Loss:  5.772
# Epoch   0 Batch   29/1077 - Train Accuracy:  0.161, Validation Accuracy:  0.241, Loss:  5.768
# Epoch   0 Batch   30/1077 - Train Accuracy:  0.164, Validation Accuracy:  0.239, Loss:  5.774
# Epoch   0 Batch   31/1077 - Train Accuracy:  0.174, Validation Accuracy:  0.237, Loss:  5.757
# Epoch   0 Batch   32/1077 - Train Accuracy:  0.199, Validation Accuracy:  0.238, Loss:  5.716
# Epoch   0 Batch   33/1077 - Train Accuracy:  0.187, Validation Accuracy:  0.236, Loss:  5.717
# Epoch   0 Batch   34/1077 - Train Accuracy:  0.185, Validation Accuracy:  0.262, Loss:  5.748
# Epoch   0 Batch   35/1077 - Train Accuracy:  0.227, Validation Accuracy:  0.294, Loss:  5.741
# Epoch   0 Batch   36/1077 - Train Accuracy:  0.263, Validation Accuracy:  0.306, Loss:  5.720
# Epoch   0 Batch   37/1077 - Train Accuracy:  0.231, Validation Accuracy:  0.308, Loss:  5.742
# Epoch   0 Batch   38/1077 - Train Accuracy:  0.191, Validation Accuracy:  0.308, Loss:  5.753
# Epoch   0 Batch   39/1077 - Train Accuracy:  0.243, Validation Accuracy:  0.307, Loss:  5.722
# Epoch   0 Batch   40/1077 - Train Accuracy:  0.233, Validation Accuracy:  0.306, Loss:  5.697
# Epoch   0 Batch   41/1077 - Train Accuracy:  0.252, Validation Accuracy:  0.306, Loss:  5.697
# Epoch   0 Batch   42/1077 - Train Accuracy:  0.238, Validation Accuracy:  0.307, Loss:  5.680
# Epoch   0 Batch   43/1077 - Train Accuracy:  0.186, Validation Accuracy:  0.306, Loss:  5.739
# Epoch   0 Batch   44/1077 - Train Accuracy:  0.181, Validation Accuracy:  0.306, Loss:  5.729
# Epoch   0 Batch   45/1077 - Train Accuracy:  0.231, Validation Accuracy:  0.306, Loss:  5.683
# Epoch   0 Batch   46/1077 - Train Accuracy:  0.218, Validation Accuracy:  0.307, Loss:  5.692
# Epoch   0 Batch   47/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.309, Loss:  5.662
# Epoch   0 Batch   48/1077 - Train Accuracy:  0.258, Validation Accuracy:  0.310, Loss:  5.625
# Epoch   0 Batch   49/1077 - Train Accuracy:  0.265, Validation Accuracy:  0.312, Loss:  5.635
# Epoch   0 Batch   50/1077 - Train Accuracy:  0.231, Validation Accuracy:  0.314, Loss:  5.664
# Epoch   0 Batch   51/1077 - Train Accuracy:  0.270, Validation Accuracy:  0.316, Loss:  5.639
# Epoch   0 Batch   52/1077 - Train Accuracy:  0.239, Validation Accuracy:  0.316, Loss:  5.632
# Epoch   0 Batch   53/1077 - Train Accuracy:  0.233, Validation Accuracy:  0.317, Loss:  5.633
# Epoch   0 Batch   54/1077 - Train Accuracy:  0.239, Validation Accuracy:  0.317, Loss:  5.624
# Epoch   0 Batch   55/1077 - Train Accuracy:  0.272, Validation Accuracy:  0.319, Loss:  5.569
# Epoch   0 Batch   56/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.320, Loss:  5.579
# Epoch   0 Batch   57/1077 - Train Accuracy:  0.322, Validation Accuracy:  0.322, Loss:  5.460
# Epoch   0 Batch   58/1077 - Train Accuracy:  0.258, Validation Accuracy:  0.322, Loss:  5.559
# Epoch   0 Batch   59/1077 - Train Accuracy:  0.210, Validation Accuracy:  0.323, Loss:  5.619
# Epoch   0 Batch   60/1077 - Train Accuracy:  0.276, Validation Accuracy:  0.322, Loss:  5.511
# Epoch   0 Batch   61/1077 - Train Accuracy:  0.258, Validation Accuracy:  0.320, Loss:  5.523
# Epoch   0 Batch   62/1077 - Train Accuracy:  0.211, Validation Accuracy:  0.319, Loss:  5.593
# Epoch   0 Batch   63/1077 - Train Accuracy:  0.284, Validation Accuracy:  0.319, Loss:  5.455
# Epoch   0 Batch   64/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.319, Loss:  5.493
# Epoch   0 Batch   65/1077 - Train Accuracy:  0.201, Validation Accuracy:  0.319, Loss:  5.586
# Epoch   0 Batch   66/1077 - Train Accuracy:  0.235, Validation Accuracy:  0.319, Loss:  5.480
# Epoch   0 Batch   67/1077 - Train Accuracy:  0.288, Validation Accuracy:  0.319, Loss:  5.370
# Epoch   0 Batch   68/1077 - Train Accuracy:  0.234, Validation Accuracy:  0.319, Loss:  5.494
# Epoch   0 Batch   69/1077 - Train Accuracy:  0.277, Validation Accuracy:  0.319, Loss:  5.375
# Epoch   0 Batch   70/1077 - Train Accuracy:  0.204, Validation Accuracy:  0.319, Loss:  5.480
# Epoch   0 Batch   71/1077 - Train Accuracy:  0.234, Validation Accuracy:  0.319, Loss:  5.434
# Epoch   0 Batch   72/1077 - Train Accuracy:  0.240, Validation Accuracy:  0.319, Loss:  5.431
# Epoch   0 Batch   73/1077 - Train Accuracy:  0.248, Validation Accuracy:  0.319, Loss:  5.390
# Epoch   0 Batch   74/1077 - Train Accuracy:  0.278, Validation Accuracy:  0.319, Loss:  5.305
# Epoch   0 Batch   75/1077 - Train Accuracy:  0.257, Validation Accuracy:  0.319, Loss:  5.326
# Epoch   0 Batch   76/1077 - Train Accuracy:  0.248, Validation Accuracy:  0.319, Loss:  5.351
# Epoch   0 Batch   77/1077 - Train Accuracy:  0.233, Validation Accuracy:  0.319, Loss:  5.341
# Epoch   0 Batch   78/1077 - Train Accuracy:  0.204, Validation Accuracy:  0.319, Loss:  5.395
# Epoch   0 Batch   79/1077 - Train Accuracy:  0.256, Validation Accuracy:  0.319, Loss:  5.267
# Epoch   0 Batch   80/1077 - Train Accuracy:  0.250, Validation Accuracy:  0.319, Loss:  5.282
# Epoch   0 Batch   81/1077 - Train Accuracy:  0.248, Validation Accuracy:  0.319, Loss:  5.229
# Epoch   0 Batch   82/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.319, Loss:  5.017
# Epoch   0 Batch   83/1077 - Train Accuracy:  0.213, Validation Accuracy:  0.319, Loss:  5.282
# Epoch   0 Batch   84/1077 - Train Accuracy:  0.244, Validation Accuracy:  0.319, Loss:  5.158
# Epoch   0 Batch   85/1077 - Train Accuracy:  0.255, Validation Accuracy:  0.319, Loss:  5.160
# Epoch   0 Batch   86/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.319, Loss:  5.146
# Epoch   0 Batch   87/1077 - Train Accuracy:  0.266, Validation Accuracy:  0.319, Loss:  5.107
# Epoch   0 Batch   88/1077 - Train Accuracy:  0.253, Validation Accuracy:  0.319, Loss:  5.135
# Epoch   0 Batch   89/1077 - Train Accuracy:  0.242, Validation Accuracy:  0.319, Loss:  5.121
# Epoch   0 Batch   90/1077 - Train Accuracy:  0.238, Validation Accuracy:  0.319, Loss:  5.120
# Epoch   0 Batch   91/1077 - Train Accuracy:  0.311, Validation Accuracy:  0.319, Loss:  4.939
# Epoch   0 Batch   92/1077 - Train Accuracy:  0.273, Validation Accuracy:  0.319, Loss:  5.051
# Epoch   0 Batch   93/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.319, Loss:  5.082
# Epoch   0 Batch   94/1077 - Train Accuracy:  0.263, Validation Accuracy:  0.319, Loss:  5.037
# Epoch   0 Batch   95/1077 - Train Accuracy:  0.295, Validation Accuracy:  0.319, Loss:  4.963
# Epoch   0 Batch   96/1077 - Train Accuracy:  0.265, Validation Accuracy:  0.319, Loss:  5.010
# Epoch   0 Batch   97/1077 - Train Accuracy:  0.278, Validation Accuracy:  0.319, Loss:  4.928
# Epoch   0 Batch   98/1077 - Train Accuracy:  0.304, Validation Accuracy:  0.319, Loss:  4.914
# Epoch   0 Batch   99/1077 - Train Accuracy:  0.242, Validation Accuracy:  0.321, Loss:  5.076
# Epoch   0 Batch  100/1077 - Train Accuracy:  0.247, Validation Accuracy:  0.326, Loss:  5.038
# Epoch   0 Batch  101/1077 - Train Accuracy:  0.255, Validation Accuracy:  0.329, Loss:  5.043
# Epoch   0 Batch  102/1077 - Train Accuracy:  0.294, Validation Accuracy:  0.333, Loss:  4.941
# Epoch   0 Batch  103/1077 - Train Accuracy:  0.219, Validation Accuracy:  0.335, Loss:  5.120
# Epoch   0 Batch  104/1077 - Train Accuracy:  0.214, Validation Accuracy:  0.335, Loss:  5.134
# Epoch   0 Batch  105/1077 - Train Accuracy:  0.281, Validation Accuracy:  0.335, Loss:  4.976
# Epoch   0 Batch  106/1077 - Train Accuracy:  0.266, Validation Accuracy:  0.335, Loss:  5.014
# Epoch   0 Batch  107/1077 - Train Accuracy:  0.304, Validation Accuracy:  0.336, Loss:  4.896
# Epoch   0 Batch  108/1077 - Train Accuracy:  0.332, Validation Accuracy:  0.336, Loss:  4.838
# Epoch   0 Batch  109/1077 - Train Accuracy:  0.289, Validation Accuracy:  0.336, Loss:  4.932
# Epoch   0 Batch  110/1077 - Train Accuracy:  0.282, Validation Accuracy:  0.336, Loss:  4.880
# Epoch   0 Batch  111/1077 - Train Accuracy:  0.260, Validation Accuracy:  0.336, Loss:  4.947
# Epoch   0 Batch  112/1077 - Train Accuracy:  0.280, Validation Accuracy:  0.336, Loss:  4.911
# Epoch   0 Batch  113/1077 - Train Accuracy:  0.266, Validation Accuracy:  0.336, Loss:  4.996
# Epoch   0 Batch  114/1077 - Train Accuracy:  0.314, Validation Accuracy:  0.337, Loss:  4.874
# Epoch   0 Batch  115/1077 - Train Accuracy:  0.280, Validation Accuracy:  0.337, Loss:  4.868
# Epoch   0 Batch  116/1077 - Train Accuracy:  0.249, Validation Accuracy:  0.337, Loss:  4.964
# Epoch   0 Batch  117/1077 - Train Accuracy:  0.255, Validation Accuracy:  0.337, Loss:  4.931
# Epoch   0 Batch  118/1077 - Train Accuracy:  0.219, Validation Accuracy:  0.337, Loss:  5.041
# Epoch   0 Batch  119/1077 - Train Accuracy:  0.267, Validation Accuracy:  0.337, Loss:  4.816
# Epoch   0 Batch  120/1077 - Train Accuracy:  0.271, Validation Accuracy:  0.337, Loss:  4.895
# Epoch   0 Batch  121/1077 - Train Accuracy:  0.277, Validation Accuracy:  0.337, Loss:  4.923
# Epoch   0 Batch  122/1077 - Train Accuracy:  0.272, Validation Accuracy:  0.337, Loss:  4.815
# Epoch   0 Batch  123/1077 - Train Accuracy:  0.281, Validation Accuracy:  0.337, Loss:  4.820
# Epoch   0 Batch  124/1077 - Train Accuracy:  0.274, Validation Accuracy:  0.337, Loss:  4.850
# Epoch   0 Batch  125/1077 - Train Accuracy:  0.291, Validation Accuracy:  0.337, Loss:  4.782
# Epoch   0 Batch  126/1077 - Train Accuracy:  0.294, Validation Accuracy:  0.337, Loss:  4.841
# Epoch   0 Batch  127/1077 - Train Accuracy:  0.280, Validation Accuracy:  0.337, Loss:  4.850
# Epoch   0 Batch  128/1077 - Train Accuracy:  0.314, Validation Accuracy:  0.337, Loss:  4.682
# Epoch   0 Batch  129/1077 - Train Accuracy:  0.297, Validation Accuracy:  0.337, Loss:  4.844
# Epoch   0 Batch  130/1077 - Train Accuracy:  0.300, Validation Accuracy:  0.337, Loss:  4.719
# Epoch   0 Batch  131/1077 - Train Accuracy:  0.264, Validation Accuracy:  0.336, Loss:  4.770
# Epoch   0 Batch  132/1077 - Train Accuracy:  0.265, Validation Accuracy:  0.336, Loss:  4.796
# Epoch   0 Batch  133/1077 - Train Accuracy:  0.236, Validation Accuracy:  0.336, Loss:  4.872
# Epoch   0 Batch  134/1077 - Train Accuracy:  0.301, Validation Accuracy:  0.336, Loss:  4.789
# Epoch   0 Batch  135/1077 - Train Accuracy:  0.256, Validation Accuracy:  0.336, Loss:  4.781
# Epoch   0 Batch  136/1077 - Train Accuracy:  0.274, Validation Accuracy:  0.336, Loss:  4.746
# Epoch   0 Batch  137/1077 - Train Accuracy:  0.308, Validation Accuracy:  0.336, Loss:  4.667
# Epoch   0 Batch  138/1077 - Train Accuracy:  0.265, Validation Accuracy:  0.336, Loss:  4.803
# Epoch   0 Batch  139/1077 - Train Accuracy:  0.280, Validation Accuracy:  0.337, Loss:  4.744
# Epoch   0 Batch  140/1077 - Train Accuracy:  0.234, Validation Accuracy:  0.338, Loss:  4.876
# Epoch   0 Batch  141/1077 - Train Accuracy:  0.272, Validation Accuracy:  0.339, Loss:  4.738
# Epoch   0 Batch  142/1077 - Train Accuracy:  0.308, Validation Accuracy:  0.339, Loss:  4.670
# Epoch   0 Batch  143/1077 - Train Accuracy:  0.282, Validation Accuracy:  0.339, Loss:  4.744
# Epoch   0 Batch  144/1077 - Train Accuracy:  0.240, Validation Accuracy:  0.339, Loss:  4.786
# Epoch   0 Batch  145/1077 - Train Accuracy:  0.276, Validation Accuracy:  0.339, Loss:  4.704
# Epoch   0 Batch  146/1077 - Train Accuracy:  0.310, Validation Accuracy:  0.339, Loss:  4.656
# Epoch   0 Batch  147/1077 - Train Accuracy:  0.261, Validation Accuracy:  0.339, Loss:  4.791
# Epoch   0 Batch  148/1077 - Train Accuracy:  0.286, Validation Accuracy:  0.339, Loss:  4.716
# Epoch   0 Batch  149/1077 - Train Accuracy:  0.278, Validation Accuracy:  0.339, Loss:  4.674
# Epoch   0 Batch  150/1077 - Train Accuracy:  0.313, Validation Accuracy:  0.339, Loss:  4.615
# Epoch   0 Batch  151/1077 - Train Accuracy:  0.310, Validation Accuracy:  0.339, Loss:  4.585
# Epoch   0 Batch  152/1077 - Train Accuracy:  0.293, Validation Accuracy:  0.339, Loss:  4.614
# Epoch   0 Batch  153/1077 - Train Accuracy:  0.278, Validation Accuracy:  0.343, Loss:  4.687
# Epoch   0 Batch  154/1077 - Train Accuracy:  0.238, Validation Accuracy:  0.343, Loss:  4.774
# Epoch   0 Batch  155/1077 - Train Accuracy:  0.283, Validation Accuracy:  0.343, Loss:  4.664
# Epoch   0 Batch  156/1077 - Train Accuracy:  0.268, Validation Accuracy:  0.343, Loss:  4.730
# Epoch   0 Batch  157/1077 - Train Accuracy:  0.282, Validation Accuracy:  0.343, Loss:  4.699
# Epoch   0 Batch  158/1077 - Train Accuracy:  0.314, Validation Accuracy:  0.343, Loss:  4.569
# Epoch   0 Batch  159/1077 - Train Accuracy:  0.304, Validation Accuracy:  0.343, Loss:  4.618
# Epoch   0 Batch  160/1077 - Train Accuracy:  0.280, Validation Accuracy:  0.343, Loss:  4.704
# Epoch   0 Batch  161/1077 - Train Accuracy:  0.275, Validation Accuracy:  0.347, Loss:  4.683
# Epoch   0 Batch  162/1077 - Train Accuracy:  0.295, Validation Accuracy:  0.351, Loss:  4.646
# Epoch   0 Batch  163/1077 - Train Accuracy:  0.252, Validation Accuracy:  0.351, Loss:  4.735
# Epoch   0 Batch  164/1077 - Train Accuracy:  0.277, Validation Accuracy:  0.350, Loss:  4.690
# Epoch   0 Batch  165/1077 - Train Accuracy:  0.271, Validation Accuracy:  0.350, Loss:  4.691
# Epoch   0 Batch  166/1077 - Train Accuracy:  0.308, Validation Accuracy:  0.351, Loss:  4.612
# Epoch   0 Batch  167/1077 - Train Accuracy:  0.274, Validation Accuracy:  0.351, Loss:  4.656
# Epoch   0 Batch  168/1077 - Train Accuracy:  0.253, Validation Accuracy:  0.351, Loss:  4.688
# Epoch   0 Batch  169/1077 - Train Accuracy:  0.331, Validation Accuracy:  0.351, Loss:  4.555
# Epoch   0 Batch  170/1077 - Train Accuracy:  0.268, Validation Accuracy:  0.353, Loss:  4.676
# Epoch   0 Batch  171/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.360, Loss:  4.461
# Epoch   0 Batch  172/1077 - Train Accuracy:  0.320, Validation Accuracy:  0.362, Loss:  4.552
# Epoch   0 Batch  173/1077 - Train Accuracy:  0.272, Validation Accuracy:  0.364, Loss:  4.731
# Epoch   0 Batch  174/1077 - Train Accuracy:  0.312, Validation Accuracy:  0.368, Loss:  4.664
# Epoch   0 Batch  175/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.371, Loss:  4.584
# Epoch   0 Batch  176/1077 - Train Accuracy:  0.303, Validation Accuracy:  0.374, Loss:  4.590
# Epoch   0 Batch  177/1077 - Train Accuracy:  0.292, Validation Accuracy:  0.376, Loss:  4.672
# Epoch   0 Batch  178/1077 - Train Accuracy:  0.325, Validation Accuracy:  0.377, Loss:  4.587
# Epoch   0 Batch  179/1077 - Train Accuracy:  0.291, Validation Accuracy:  0.378, Loss:  4.643
# Epoch   0 Batch  180/1077 - Train Accuracy:  0.314, Validation Accuracy:  0.370, Loss:  4.599
# Epoch   0 Batch  181/1077 - Train Accuracy:  0.310, Validation Accuracy:  0.368, Loss:  4.528
# Epoch   0 Batch  182/1077 - Train Accuracy:  0.335, Validation Accuracy:  0.367, Loss:  4.513
# Epoch   0 Batch  183/1077 - Train Accuracy:  0.298, Validation Accuracy:  0.367, Loss:  4.571
# Epoch   0 Batch  184/1077 - Train Accuracy:  0.311, Validation Accuracy:  0.370, Loss:  4.586
# Epoch   0 Batch  185/1077 - Train Accuracy:  0.293, Validation Accuracy:  0.358, Loss:  4.592
# Epoch   0 Batch  186/1077 - Train Accuracy:  0.267, Validation Accuracy:  0.359, Loss:  4.679
# Epoch   0 Batch  187/1077 - Train Accuracy:  0.313, Validation Accuracy:  0.365, Loss:  4.535
# Epoch   0 Batch  188/1077 - Train Accuracy:  0.319, Validation Accuracy:  0.371, Loss:  4.554
# Epoch   0 Batch  189/1077 - Train Accuracy:  0.315, Validation Accuracy:  0.374, Loss:  4.608
# Epoch   0 Batch  190/1077 - Train Accuracy:  0.323, Validation Accuracy:  0.374, Loss:  4.524
# Epoch   0 Batch  191/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.380, Loss:  4.498
# Epoch   0 Batch  192/1077 - Train Accuracy:  0.322, Validation Accuracy:  0.380, Loss:  4.583
# Epoch   0 Batch  193/1077 - Train Accuracy:  0.329, Validation Accuracy:  0.381, Loss:  4.499
# Epoch   0 Batch  194/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.383, Loss:  4.500
# Epoch   0 Batch  195/1077 - Train Accuracy:  0.313, Validation Accuracy:  0.380, Loss:  4.618
# Epoch   0 Batch  196/1077 - Train Accuracy:  0.325, Validation Accuracy:  0.378, Loss:  4.597
# Epoch   0 Batch  197/1077 - Train Accuracy:  0.329, Validation Accuracy:  0.377, Loss:  4.481
# Epoch   0 Batch  198/1077 - Train Accuracy:  0.341, Validation Accuracy:  0.369, Loss:  4.517
# Epoch   0 Batch  199/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.368, Loss:  4.506
# Epoch   0 Batch  200/1077 - Train Accuracy:  0.305, Validation Accuracy:  0.369, Loss:  4.524
# Epoch   0 Batch  201/1077 - Train Accuracy:  0.322, Validation Accuracy:  0.377, Loss:  4.517
# Epoch   0 Batch  202/1077 - Train Accuracy:  0.323, Validation Accuracy:  0.376, Loss:  4.586
# Epoch   0 Batch  203/1077 - Train Accuracy:  0.324, Validation Accuracy:  0.381, Loss:  4.532
# Epoch   0 Batch  204/1077 - Train Accuracy:  0.333, Validation Accuracy:  0.382, Loss:  4.493
# Epoch   0 Batch  205/1077 - Train Accuracy:  0.326, Validation Accuracy:  0.384, Loss:  4.541
# Epoch   0 Batch  206/1077 - Train Accuracy:  0.326, Validation Accuracy:  0.384, Loss:  4.556
# Epoch   0 Batch  207/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.384, Loss:  4.533
# Epoch   0 Batch  208/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.385, Loss:  4.503
# Epoch   0 Batch  209/1077 - Train Accuracy:  0.361, Validation Accuracy:  0.385, Loss:  4.474
# Epoch   0 Batch  210/1077 - Train Accuracy:  0.351, Validation Accuracy:  0.384, Loss:  4.444
# Epoch   0 Batch  211/1077 - Train Accuracy:  0.327, Validation Accuracy:  0.385, Loss:  4.549
# Epoch   0 Batch  212/1077 - Train Accuracy:  0.351, Validation Accuracy:  0.385, Loss:  4.476
# Epoch   0 Batch  213/1077 - Train Accuracy:  0.330, Validation Accuracy:  0.387, Loss:  4.517
# Epoch   0 Batch  214/1077 - Train Accuracy:  0.329, Validation Accuracy:  0.392, Loss:  4.577
# Epoch   0 Batch  215/1077 - Train Accuracy:  0.344, Validation Accuracy:  0.406, Loss:  4.500
# Epoch   0 Batch  216/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.408, Loss:  4.539
# Epoch   0 Batch  217/1077 - Train Accuracy:  0.357, Validation Accuracy:  0.407, Loss:  4.497
# Epoch   0 Batch  218/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.408, Loss:  4.565
# Epoch   0 Batch  219/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.408, Loss:  4.502
# Epoch   0 Batch  220/1077 - Train Accuracy:  0.315, Validation Accuracy:  0.408, Loss:  4.627
# Epoch   0 Batch  221/1077 - Train Accuracy:  0.325, Validation Accuracy:  0.405, Loss:  4.534
# Epoch   0 Batch  222/1077 - Train Accuracy:  0.335, Validation Accuracy:  0.407, Loss:  4.545
# Epoch   0 Batch  223/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.408, Loss:  4.356
# Epoch   0 Batch  224/1077 - Train Accuracy:  0.339, Validation Accuracy:  0.407, Loss:  4.477
# Epoch   0 Batch  225/1077 - Train Accuracy:  0.341, Validation Accuracy:  0.407, Loss:  4.492
# Epoch   0 Batch  226/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.407, Loss:  4.519
# Epoch   0 Batch  227/1077 - Train Accuracy:  0.328, Validation Accuracy:  0.406, Loss:  4.526
# Epoch   0 Batch  228/1077 - Train Accuracy:  0.351, Validation Accuracy:  0.405, Loss:  4.496
# Epoch   0 Batch  229/1077 - Train Accuracy:  0.345, Validation Accuracy:  0.406, Loss:  4.495
# Epoch   0 Batch  230/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.404, Loss:  4.368
# Epoch   0 Batch  231/1077 - Train Accuracy:  0.355, Validation Accuracy:  0.404, Loss:  4.494
# Epoch   0 Batch  232/1077 - Train Accuracy:  0.308, Validation Accuracy:  0.404, Loss:  4.578
# Epoch   0 Batch  233/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.406, Loss:  4.495
# Epoch   0 Batch  234/1077 - Train Accuracy:  0.386, Validation Accuracy:  0.405, Loss:  4.419
# Epoch   0 Batch  235/1077 - Train Accuracy:  0.397, Validation Accuracy:  0.409, Loss:  4.338
# Epoch   0 Batch  236/1077 - Train Accuracy:  0.346, Validation Accuracy:  0.409, Loss:  4.530
# Epoch   0 Batch  237/1077 - Train Accuracy:  0.368, Validation Accuracy:  0.411, Loss:  4.412
# Epoch   0 Batch  238/1077 - Train Accuracy:  0.356, Validation Accuracy:  0.411, Loss:  4.482
# Epoch   0 Batch  239/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.411, Loss:  4.403
# Epoch   0 Batch  240/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.401, Loss:  4.503
# Epoch   0 Batch  241/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.401, Loss:  4.385
# Epoch   0 Batch  242/1077 - Train Accuracy:  0.328, Validation Accuracy:  0.401, Loss:  4.508
# Epoch   0 Batch  243/1077 - Train Accuracy:  0.316, Validation Accuracy:  0.400, Loss:  4.532
# Epoch   0 Batch  244/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.402, Loss:  4.325
# Epoch   0 Batch  245/1077 - Train Accuracy:  0.367, Validation Accuracy:  0.403, Loss:  4.389
# Epoch   0 Batch  246/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.402, Loss:  4.487
# Epoch   0 Batch  247/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.402, Loss:  4.329
# Epoch   0 Batch  248/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.402, Loss:  4.415
# Epoch   0 Batch  249/1077 - Train Accuracy:  0.338, Validation Accuracy:  0.402, Loss:  4.503
# Epoch   0 Batch  250/1077 - Train Accuracy:  0.397, Validation Accuracy:  0.403, Loss:  4.332
# Epoch   0 Batch  251/1077 - Train Accuracy:  0.365, Validation Accuracy:  0.403, Loss:  4.453
# Epoch   0 Batch  252/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.403, Loss:  4.429
# Epoch   0 Batch  253/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.403, Loss:  4.332
# Epoch   0 Batch  254/1077 - Train Accuracy:  0.344, Validation Accuracy:  0.403, Loss:  4.402
# Epoch   0 Batch  255/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.403, Loss:  4.392
# Epoch   0 Batch  256/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.403, Loss:  4.459
# Epoch   0 Batch  257/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.404, Loss:  4.276
# Epoch   0 Batch  258/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.404, Loss:  4.350
# Epoch   0 Batch  259/1077 - Train Accuracy:  0.358, Validation Accuracy:  0.406, Loss:  4.386
# Epoch   0 Batch  260/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.411, Loss:  4.404
# Epoch   0 Batch  261/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.412, Loss:  4.401
# Epoch   0 Batch  262/1077 - Train Accuracy:  0.359, Validation Accuracy:  0.414, Loss:  4.446
# Epoch   0 Batch  263/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.415, Loss:  4.401
# Epoch   0 Batch  264/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.415, Loss:  4.439
# Epoch   0 Batch  265/1077 - Train Accuracy:  0.361, Validation Accuracy:  0.414, Loss:  4.341
# Epoch   0 Batch  266/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.414, Loss:  4.338
# Epoch   0 Batch  267/1077 - Train Accuracy:  0.390, Validation Accuracy:  0.414, Loss:  4.319
# Epoch   0 Batch  268/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.413, Loss:  4.465
# Epoch   0 Batch  269/1077 - Train Accuracy:  0.333, Validation Accuracy:  0.419, Loss:  4.486
# Epoch   0 Batch  270/1077 - Train Accuracy:  0.336, Validation Accuracy:  0.427, Loss:  4.468
# Epoch   0 Batch  271/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.428, Loss:  4.472
# Epoch   0 Batch  272/1077 - Train Accuracy:  0.390, Validation Accuracy:  0.430, Loss:  4.372
# Epoch   0 Batch  273/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.429, Loss:  4.380
# Epoch   0 Batch  274/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.429, Loss:  4.378
# Epoch   0 Batch  275/1077 - Train Accuracy:  0.406, Validation Accuracy:  0.428, Loss:  4.315
# Epoch   0 Batch  276/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.428, Loss:  4.394
# Epoch   0 Batch  277/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.428, Loss:  4.331
# Epoch   0 Batch  278/1077 - Train Accuracy:  0.359, Validation Accuracy:  0.429, Loss:  4.431
# Epoch   0 Batch  279/1077 - Train Accuracy:  0.349, Validation Accuracy:  0.429, Loss:  4.461
# Epoch   0 Batch  280/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.428, Loss:  4.368
# Epoch   0 Batch  281/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.427, Loss:  4.383
# Epoch   0 Batch  282/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.428, Loss:  4.368
# Epoch   0 Batch  283/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.426, Loss:  4.421
# Epoch   0 Batch  284/1077 - Train Accuracy:  0.359, Validation Accuracy:  0.428, Loss:  4.433
# Epoch   0 Batch  285/1077 - Train Accuracy:  0.406, Validation Accuracy:  0.425, Loss:  4.228
# Epoch   0 Batch  286/1077 - Train Accuracy:  0.412, Validation Accuracy:  0.426, Loss:  4.325
# Epoch   0 Batch  287/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.425, Loss:  4.363
# Epoch   0 Batch  288/1077 - Train Accuracy:  0.354, Validation Accuracy:  0.427, Loss:  4.477
# Epoch   0 Batch  289/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.426, Loss:  4.294
# Epoch   0 Batch  290/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.428, Loss:  4.374
# Epoch   0 Batch  291/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.428, Loss:  4.299
# Epoch   0 Batch  292/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.428, Loss:  4.293
# Epoch   0 Batch  293/1077 - Train Accuracy:  0.344, Validation Accuracy:  0.427, Loss:  4.488
# Epoch   0 Batch  294/1077 - Train Accuracy:  0.429, Validation Accuracy:  0.426, Loss:  4.277
# Epoch   0 Batch  295/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.424, Loss:  4.414
# Epoch   0 Batch  296/1077 - Train Accuracy:  0.397, Validation Accuracy:  0.425, Loss:  4.318
# Epoch   0 Batch  297/1077 - Train Accuracy:  0.351, Validation Accuracy:  0.427, Loss:  4.470
# Epoch   0 Batch  298/1077 - Train Accuracy:  0.366, Validation Accuracy:  0.426, Loss:  4.370
# Epoch   0 Batch  299/1077 - Train Accuracy:  0.377, Validation Accuracy:  0.426, Loss:  4.354
# Epoch   0 Batch  300/1077 - Train Accuracy:  0.328, Validation Accuracy:  0.428, Loss:  4.489
# Epoch   0 Batch  301/1077 - Train Accuracy:  0.365, Validation Accuracy:  0.424, Loss:  4.401
# Epoch   0 Batch  302/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.429, Loss:  4.380
# Epoch   0 Batch  303/1077 - Train Accuracy:  0.360, Validation Accuracy:  0.436, Loss:  4.376
# Epoch   0 Batch  304/1077 - Train Accuracy:  0.402, Validation Accuracy:  0.438, Loss:  4.288
# Epoch   0 Batch  305/1077 - Train Accuracy:  0.372, Validation Accuracy:  0.434, Loss:  4.396
# Epoch   0 Batch  306/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.435, Loss:  4.315
# Epoch   0 Batch  307/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.429, Loss:  4.337
# Epoch   0 Batch  308/1077 - Train Accuracy:  0.340, Validation Accuracy:  0.429, Loss:  4.410
# Epoch   0 Batch  309/1077 - Train Accuracy:  0.392, Validation Accuracy:  0.430, Loss:  4.335
# Epoch   0 Batch  310/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.432, Loss:  4.367
# Epoch   0 Batch  311/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.433, Loss:  4.178
# Epoch   0 Batch  312/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.435, Loss:  4.345
# Epoch   0 Batch  313/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.433, Loss:  4.385
# Epoch   0 Batch  314/1077 - Train Accuracy:  0.365, Validation Accuracy:  0.435, Loss:  4.379
# Epoch   0 Batch  315/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.434, Loss:  4.317
# Epoch   0 Batch  316/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.434, Loss:  4.212
# Epoch   0 Batch  317/1077 - Train Accuracy:  0.358, Validation Accuracy:  0.427, Loss:  4.409
# Epoch   0 Batch  318/1077 - Train Accuracy:  0.360, Validation Accuracy:  0.427, Loss:  4.377
# Epoch   0 Batch  319/1077 - Train Accuracy:  0.354, Validation Accuracy:  0.430, Loss:  4.326
# Epoch   0 Batch  320/1077 - Train Accuracy:  0.378, Validation Accuracy:  0.430, Loss:  4.321
# Epoch   0 Batch  321/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.429, Loss:  4.276
# Epoch   0 Batch  322/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.428, Loss:  4.291
# Epoch   0 Batch  323/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.428, Loss:  4.326
# Epoch   0 Batch  324/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.429, Loss:  4.308
# Epoch   0 Batch  325/1077 - Train Accuracy:  0.413, Validation Accuracy:  0.430, Loss:  4.166
# Epoch   0 Batch  326/1077 - Train Accuracy:  0.411, Validation Accuracy:  0.430, Loss:  4.233
# Epoch   0 Batch  327/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.430, Loss:  4.412
# Epoch   0 Batch  328/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.431, Loss:  4.287
# Epoch   0 Batch  329/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.434, Loss:  4.361
# Epoch   0 Batch  330/1077 - Train Accuracy:  0.387, Validation Accuracy:  0.436, Loss:  4.296
# Epoch   0 Batch  331/1077 - Train Accuracy:  0.369, Validation Accuracy:  0.438, Loss:  4.369
# Epoch   0 Batch  332/1077 - Train Accuracy:  0.402, Validation Accuracy:  0.439, Loss:  4.283
# Epoch   0 Batch  333/1077 - Train Accuracy:  0.369, Validation Accuracy:  0.439, Loss:  4.381
# Epoch   0 Batch  334/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.435, Loss:  4.296
# Epoch   0 Batch  335/1077 - Train Accuracy:  0.428, Validation Accuracy:  0.435, Loss:  4.257
# Epoch   0 Batch  336/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.434, Loss:  4.333
# Epoch   0 Batch  337/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.434, Loss:  4.360
# Epoch   0 Batch  338/1077 - Train Accuracy:  0.366, Validation Accuracy:  0.431, Loss:  4.344
# Epoch   0 Batch  339/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.432, Loss:  4.228
# Epoch   0 Batch  340/1077 - Train Accuracy:  0.324, Validation Accuracy:  0.434, Loss:  4.396
# Epoch   0 Batch  341/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.435, Loss:  4.270
# Epoch   0 Batch  342/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.436, Loss:  4.270
# Epoch   0 Batch  343/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.437, Loss:  4.335
# Epoch   0 Batch  344/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.440, Loss:  4.347
# Epoch   0 Batch  345/1077 - Train Accuracy:  0.392, Validation Accuracy:  0.438, Loss:  4.260
# Epoch   0 Batch  346/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.440, Loss:  4.324
# Epoch   0 Batch  347/1077 - Train Accuracy:  0.400, Validation Accuracy:  0.442, Loss:  4.241
# Epoch   0 Batch  348/1077 - Train Accuracy:  0.394, Validation Accuracy:  0.440, Loss:  4.262
# Epoch   0 Batch  349/1077 - Train Accuracy:  0.357, Validation Accuracy:  0.434, Loss:  4.242
# Epoch   0 Batch  350/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.432, Loss:  4.369
# Epoch   0 Batch  351/1077 - Train Accuracy:  0.329, Validation Accuracy:  0.431, Loss:  4.430
# Epoch   0 Batch  352/1077 - Train Accuracy:  0.333, Validation Accuracy:  0.435, Loss:  4.377
# Epoch   0 Batch  353/1077 - Train Accuracy:  0.338, Validation Accuracy:  0.439, Loss:  4.433
# Epoch   0 Batch  354/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.440, Loss:  4.286
# Epoch   0 Batch  355/1077 - Train Accuracy:  0.400, Validation Accuracy:  0.440, Loss:  4.217
# Epoch   0 Batch  356/1077 - Train Accuracy:  0.387, Validation Accuracy:  0.442, Loss:  4.265
# Epoch   0 Batch  357/1077 - Train Accuracy:  0.431, Validation Accuracy:  0.444, Loss:  4.208
# Epoch   0 Batch  358/1077 - Train Accuracy:  0.347, Validation Accuracy:  0.439, Loss:  4.357
# Epoch   0 Batch  359/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.436, Loss:  4.355
# Epoch   0 Batch  360/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.432, Loss:  4.300
# Epoch   0 Batch  361/1077 - Train Accuracy:  0.347, Validation Accuracy:  0.429, Loss:  4.307
# Epoch   0 Batch  362/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.428, Loss:  4.246
# Epoch   0 Batch  363/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.430, Loss:  4.337
# Epoch   0 Batch  364/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.429, Loss:  4.300
# Epoch   0 Batch  365/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.425, Loss:  4.365
# Epoch   0 Batch  366/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.429, Loss:  4.329
# Epoch   0 Batch  367/1077 - Train Accuracy:  0.399, Validation Accuracy:  0.433, Loss:  4.223
# Epoch   0 Batch  368/1077 - Train Accuracy:  0.374, Validation Accuracy:  0.439, Loss:  4.287
# Epoch   0 Batch  369/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.437, Loss:  4.300
# Epoch   0 Batch  370/1077 - Train Accuracy:  0.390, Validation Accuracy:  0.438, Loss:  4.225
# Epoch   0 Batch  371/1077 - Train Accuracy:  0.377, Validation Accuracy:  0.438, Loss:  4.269
# Epoch   0 Batch  372/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.440, Loss:  4.286
# Epoch   0 Batch  373/1077 - Train Accuracy:  0.415, Validation Accuracy:  0.439, Loss:  4.208
# Epoch   0 Batch  374/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.441, Loss:  4.350
# Epoch   0 Batch  375/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.440, Loss:  4.205
# Epoch   0 Batch  376/1077 - Train Accuracy:  0.417, Validation Accuracy:  0.436, Loss:  4.158
# Epoch   0 Batch  377/1077 - Train Accuracy:  0.368, Validation Accuracy:  0.431, Loss:  4.252
# Epoch   0 Batch  378/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.427, Loss:  4.334
# Epoch   0 Batch  379/1077 - Train Accuracy:  0.359, Validation Accuracy:  0.427, Loss:  4.343
# Epoch   0 Batch  380/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.429, Loss:  4.230
# Epoch   0 Batch  381/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.433, Loss:  4.230
# Epoch   0 Batch  382/1077 - Train Accuracy:  0.411, Validation Accuracy:  0.438, Loss:  4.216
# Epoch   0 Batch  383/1077 - Train Accuracy:  0.415, Validation Accuracy:  0.441, Loss:  4.153
# Epoch   0 Batch  384/1077 - Train Accuracy:  0.386, Validation Accuracy:  0.444, Loss:  4.248
# Epoch   0 Batch  385/1077 - Train Accuracy:  0.378, Validation Accuracy:  0.446, Loss:  4.300
# Epoch   0 Batch  386/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.447, Loss:  4.160
# Epoch   0 Batch  387/1077 - Train Accuracy:  0.405, Validation Accuracy:  0.448, Loss:  4.195
# Epoch   0 Batch  388/1077 - Train Accuracy:  0.412, Validation Accuracy:  0.445, Loss:  4.173
# Epoch   0 Batch  389/1077 - Train Accuracy:  0.392, Validation Accuracy:  0.444, Loss:  4.229
# Epoch   0 Batch  390/1077 - Train Accuracy:  0.341, Validation Accuracy:  0.439, Loss:  4.297
# Epoch   0 Batch  391/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.433, Loss:  4.211
# Epoch   0 Batch  392/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.430, Loss:  4.232
# Epoch   0 Batch  393/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.430, Loss:  4.236
# Epoch   0 Batch  394/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.429, Loss:  4.295
# Epoch   0 Batch  395/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.428, Loss:  4.196
# Epoch   0 Batch  396/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.427, Loss:  4.223
# Epoch   0 Batch  397/1077 - Train Accuracy:  0.413, Validation Accuracy:  0.429, Loss:  4.212
# Epoch   0 Batch  398/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.430, Loss:  4.364
# Epoch   0 Batch  399/1077 - Train Accuracy:  0.345, Validation Accuracy:  0.437, Loss:  4.366
# Epoch   0 Batch  400/1077 - Train Accuracy:  0.358, Validation Accuracy:  0.438, Loss:  4.311
# Epoch   0 Batch  401/1077 - Train Accuracy:  0.378, Validation Accuracy:  0.439, Loss:  4.225
# Epoch   0 Batch  402/1077 - Train Accuracy:  0.369, Validation Accuracy:  0.442, Loss:  4.232
# Epoch   0 Batch  403/1077 - Train Accuracy:  0.392, Validation Accuracy:  0.444, Loss:  4.241
# Epoch   0 Batch  404/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.443, Loss:  4.120
# Epoch   0 Batch  405/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.439, Loss:  4.301
# Epoch   0 Batch  406/1077 - Train Accuracy:  0.359, Validation Accuracy:  0.435, Loss:  4.330
# Epoch   0 Batch  407/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.434, Loss:  4.240
# Epoch   0 Batch  408/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.432, Loss:  4.304
# Epoch   0 Batch  409/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.432, Loss:  4.248
# Epoch   0 Batch  410/1077 - Train Accuracy:  0.337, Validation Accuracy:  0.434, Loss:  4.309
# Epoch   0 Batch  411/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.436, Loss:  4.172
# Epoch   0 Batch  412/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.435, Loss:  4.288
# Epoch   0 Batch  413/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.435, Loss:  4.245
# Epoch   0 Batch  414/1077 - Train Accuracy:  0.339, Validation Accuracy:  0.435, Loss:  4.326
# Epoch   0 Batch  415/1077 - Train Accuracy:  0.410, Validation Accuracy:  0.440, Loss:  4.165
# Epoch   0 Batch  416/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.446, Loss:  4.273
# Epoch   0 Batch  417/1077 - Train Accuracy:  0.393, Validation Accuracy:  0.452, Loss:  4.211
# Epoch   0 Batch  418/1077 - Train Accuracy:  0.381, Validation Accuracy:  0.454, Loss:  4.254
# Epoch   0 Batch  419/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.451, Loss:  4.207
# Epoch   0 Batch  420/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.443, Loss:  4.295
# Epoch   0 Batch  421/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.441, Loss:  4.200
# Epoch   0 Batch  422/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.439, Loss:  4.134
# Epoch   0 Batch  423/1077 - Train Accuracy:  0.381, Validation Accuracy:  0.436, Loss:  4.147
# Epoch   0 Batch  424/1077 - Train Accuracy:  0.348, Validation Accuracy:  0.433, Loss:  4.241
# Epoch   0 Batch  425/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.430, Loss:  4.206
# Epoch   0 Batch  426/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.429, Loss:  4.243
# Epoch   0 Batch  427/1077 - Train Accuracy:  0.365, Validation Accuracy:  0.433, Loss:  4.161
# Epoch   0 Batch  428/1077 - Train Accuracy:  0.392, Validation Accuracy:  0.433, Loss:  4.158
# Epoch   0 Batch  429/1077 - Train Accuracy:  0.361, Validation Accuracy:  0.434, Loss:  4.214
# Epoch   0 Batch  430/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.435, Loss:  4.177
# Epoch   0 Batch  431/1077 - Train Accuracy:  0.336, Validation Accuracy:  0.439, Loss:  4.268
# Epoch   0 Batch  432/1077 - Train Accuracy:  0.396, Validation Accuracy:  0.442, Loss:  4.192
# Epoch   0 Batch  433/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.449, Loss:  4.252
# Epoch   0 Batch  434/1077 - Train Accuracy:  0.360, Validation Accuracy:  0.451, Loss:  4.257
# Epoch   0 Batch  435/1077 - Train Accuracy:  0.366, Validation Accuracy:  0.451, Loss:  4.364
# Epoch   0 Batch  436/1077 - Train Accuracy:  0.402, Validation Accuracy:  0.449, Loss:  4.267
# Epoch   0 Batch  437/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.441, Loss:  4.246
# Epoch   0 Batch  438/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.438, Loss:  4.275
# Epoch   0 Batch  439/1077 - Train Accuracy:  0.361, Validation Accuracy:  0.437, Loss:  4.235
# Epoch   0 Batch  440/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.435, Loss:  4.243
# Epoch   0 Batch  441/1077 - Train Accuracy:  0.358, Validation Accuracy:  0.435, Loss:  4.214
# Epoch   0 Batch  442/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.436, Loss:  4.173
# Epoch   0 Batch  443/1077 - Train Accuracy:  0.404, Validation Accuracy:  0.439, Loss:  4.152
# Epoch   0 Batch  444/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.440, Loss:  4.223
# Epoch   0 Batch  445/1077 - Train Accuracy:  0.332, Validation Accuracy:  0.444, Loss:  4.251
# Epoch   0 Batch  446/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.447, Loss:  4.171
# Epoch   0 Batch  447/1077 - Train Accuracy:  0.381, Validation Accuracy:  0.447, Loss:  4.243
# Epoch   0 Batch  448/1077 - Train Accuracy:  0.403, Validation Accuracy:  0.447, Loss:  4.253
# Epoch   0 Batch  449/1077 - Train Accuracy:  0.360, Validation Accuracy:  0.447, Loss:  4.235
# Epoch   0 Batch  450/1077 - Train Accuracy:  0.372, Validation Accuracy:  0.447, Loss:  4.216
# Epoch   0 Batch  451/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.447, Loss:  4.088
# Epoch   0 Batch  452/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.446, Loss:  4.150
# Epoch   0 Batch  453/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.446, Loss:  4.185
# Epoch   0 Batch  454/1077 - Train Accuracy:  0.390, Validation Accuracy:  0.446, Loss:  4.180
# Epoch   0 Batch  455/1077 - Train Accuracy:  0.432, Validation Accuracy:  0.446, Loss:  4.095
# Epoch   0 Batch  456/1077 - Train Accuracy:  0.396, Validation Accuracy:  0.446, Loss:  4.238
# Epoch   0 Batch  457/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.446, Loss:  4.165
# Epoch   0 Batch  458/1077 - Train Accuracy:  0.361, Validation Accuracy:  0.447, Loss:  4.236
# Epoch   0 Batch  459/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.446, Loss:  4.177
# Epoch   0 Batch  460/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.440, Loss:  4.175
# Epoch   0 Batch  461/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.440, Loss:  4.189
# Epoch   0 Batch  462/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.441, Loss:  4.229
# Epoch   0 Batch  463/1077 - Train Accuracy:  0.374, Validation Accuracy:  0.441, Loss:  4.151
# Epoch   0 Batch  464/1077 - Train Accuracy:  0.387, Validation Accuracy:  0.442, Loss:  4.196
# Epoch   0 Batch  465/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.441, Loss:  4.298
# Epoch   0 Batch  466/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.438, Loss:  4.222
# Epoch   0 Batch  467/1077 - Train Accuracy:  0.432, Validation Accuracy:  0.438, Loss:  4.028
# Epoch   0 Batch  468/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.438, Loss:  4.193
# Epoch   0 Batch  469/1077 - Train Accuracy:  0.353, Validation Accuracy:  0.438, Loss:  4.224
# Epoch   0 Batch  470/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.436, Loss:  4.194
# Epoch   0 Batch  471/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.432, Loss:  4.122
# Epoch   0 Batch  472/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.432, Loss:  4.213
# Epoch   0 Batch  473/1077 - Train Accuracy:  0.374, Validation Accuracy:  0.438, Loss:  4.154
# Epoch   0 Batch  474/1077 - Train Accuracy:  0.355, Validation Accuracy:  0.439, Loss:  4.241
# Epoch   0 Batch  475/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.441, Loss:  4.110
# Epoch   0 Batch  476/1077 - Train Accuracy:  0.343, Validation Accuracy:  0.443, Loss:  4.235
# Epoch   0 Batch  477/1077 - Train Accuracy:  0.421, Validation Accuracy:  0.446, Loss:  4.057
# Epoch   0 Batch  478/1077 - Train Accuracy:  0.369, Validation Accuracy:  0.451, Loss:  4.247
# Epoch   0 Batch  479/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.449, Loss:  4.229
# Epoch   0 Batch  480/1077 - Train Accuracy:  0.362, Validation Accuracy:  0.451, Loss:  4.201
# Epoch   0 Batch  481/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.447, Loss:  4.143
# Epoch   0 Batch  482/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.445, Loss:  4.225
# Epoch   0 Batch  483/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.445, Loss:  4.257
# Epoch   0 Batch  484/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.445, Loss:  4.190
# Epoch   0 Batch  485/1077 - Train Accuracy:  0.371, Validation Accuracy:  0.447, Loss:  4.159
# Epoch   0 Batch  486/1077 - Train Accuracy:  0.373, Validation Accuracy:  0.447, Loss:  4.185
# Epoch   0 Batch  487/1077 - Train Accuracy:  0.360, Validation Accuracy:  0.450, Loss:  4.215
# Epoch   0 Batch  488/1077 - Train Accuracy:  0.363, Validation Accuracy:  0.451, Loss:  4.184
# Epoch   0 Batch  489/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.455, Loss:  4.181
# Epoch   0 Batch  490/1077 - Train Accuracy:  0.380, Validation Accuracy:  0.455, Loss:  4.192
# Epoch   0 Batch  491/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.453, Loss:  4.149
# Epoch   0 Batch  492/1077 - Train Accuracy:  0.387, Validation Accuracy:  0.451, Loss:  4.173
# Epoch   0 Batch  493/1077 - Train Accuracy:  0.413, Validation Accuracy:  0.450, Loss:  4.031
# Epoch   0 Batch  494/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.448, Loss:  4.214
# Epoch   0 Batch  495/1077 - Train Accuracy:  0.367, Validation Accuracy:  0.446, Loss:  4.240
# Epoch   0 Batch  496/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.446, Loss:  4.247
# Epoch   0 Batch  497/1077 - Train Accuracy:  0.352, Validation Accuracy:  0.446, Loss:  4.256
# Epoch   0 Batch  498/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.445, Loss:  4.165
# Epoch   0 Batch  499/1077 - Train Accuracy:  0.394, Validation Accuracy:  0.445, Loss:  4.095
# Epoch   0 Batch  500/1077 - Train Accuracy:  0.384, Validation Accuracy:  0.444, Loss:  4.161
# Epoch   0 Batch  501/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.451, Loss:  4.204
# Epoch   0 Batch  502/1077 - Train Accuracy:  0.396, Validation Accuracy:  0.449, Loss:  4.207
# Epoch   0 Batch  503/1077 - Train Accuracy:  0.399, Validation Accuracy:  0.451, Loss:  4.122
# Epoch   0 Batch  504/1077 - Train Accuracy:  0.365, Validation Accuracy:  0.451, Loss:  4.128
# Epoch   0 Batch  505/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.450, Loss:  4.043
# Epoch   0 Batch  506/1077 - Train Accuracy:  0.382, Validation Accuracy:  0.455, Loss:  4.205
# Epoch   0 Batch  507/1077 - Train Accuracy:  0.395, Validation Accuracy:  0.457, Loss:  4.222
# Epoch   0 Batch  508/1077 - Train Accuracy:  0.417, Validation Accuracy:  0.461, Loss:  4.110
# Epoch   0 Batch  509/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.459, Loss:  4.220
# ...
# Epoch   5 Batch  911/1077 - Train Accuracy:  0.593, Validation Accuracy:  0.561, Loss:  3.076
# Epoch   5 Batch  912/1077 - Train Accuracy:  0.568, Validation Accuracy:  0.559, Loss:  3.110
# Epoch   5 Batch  913/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.558, Loss:  3.131
# Epoch   5 Batch  914/1077 - Train Accuracy:  0.605, Validation Accuracy:  0.559, Loss:  3.080
# Epoch   5 Batch  915/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.559, Loss:  3.089
# Epoch   5 Batch  916/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.560, Loss:  3.129
# Epoch   5 Batch  917/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.562, Loss:  3.066
# Epoch   5 Batch  918/1077 - Train Accuracy:  0.572, Validation Accuracy:  0.562, Loss:  2.996
# Epoch   5 Batch  919/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.560, Loss:  3.122
# Epoch   5 Batch  920/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.559, Loss:  3.126
# Epoch   5 Batch  921/1077 - Train Accuracy:  0.509, Validation Accuracy:  0.559, Loss:  3.192
# Epoch   5 Batch  922/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.559, Loss:  3.077
# Epoch   5 Batch  923/1077 - Train Accuracy:  0.512, Validation Accuracy:  0.559, Loss:  3.156
# Epoch   5 Batch  924/1077 - Train Accuracy:  0.515, Validation Accuracy:  0.561, Loss:  3.050
# Epoch   5 Batch  925/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.561, Loss:  3.070
# Epoch   5 Batch  926/1077 - Train Accuracy:  0.556, Validation Accuracy:  0.562, Loss:  3.166
# Epoch   5 Batch  927/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.559, Loss:  3.156
# Epoch   5 Batch  928/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.561, Loss:  3.162
# Epoch   5 Batch  929/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.564, Loss:  3.076
# Epoch   5 Batch  930/1077 - Train Accuracy:  0.558, Validation Accuracy:  0.564, Loss:  3.177
# Epoch   5 Batch  931/1077 - Train Accuracy:  0.559, Validation Accuracy:  0.566, Loss:  3.112
# Epoch   5 Batch  932/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.564, Loss:  3.159
# Epoch   5 Batch  933/1077 - Train Accuracy:  0.538, Validation Accuracy:  0.564, Loss:  3.215
# Epoch   5 Batch  934/1077 - Train Accuracy:  0.533, Validation Accuracy:  0.561, Loss:  3.155
# Epoch   5 Batch  935/1077 - Train Accuracy:  0.526, Validation Accuracy:  0.561, Loss:  3.192
# Epoch   5 Batch  936/1077 - Train Accuracy:  0.538, Validation Accuracy:  0.561, Loss:  3.084
# Epoch   5 Batch  937/1077 - Train Accuracy:  0.535, Validation Accuracy:  0.561, Loss:  3.114
# Epoch   5 Batch  938/1077 - Train Accuracy:  0.555, Validation Accuracy:  0.560, Loss:  3.199
# Epoch   5 Batch  939/1077 - Train Accuracy:  0.566, Validation Accuracy:  0.559, Loss:  3.174
# Epoch   5 Batch  940/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.558, Loss:  3.183
# Epoch   5 Batch  941/1077 - Train Accuracy:  0.539, Validation Accuracy:  0.558, Loss:  3.085
# Epoch   5 Batch  942/1077 - Train Accuracy:  0.529, Validation Accuracy:  0.564, Loss:  3.160
# Epoch   5 Batch  943/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.564, Loss:  3.169
# Epoch   5 Batch  944/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.564, Loss:  3.110
# Epoch   5 Batch  945/1077 - Train Accuracy:  0.573, Validation Accuracy:  0.564, Loss:  3.114
# Epoch   5 Batch  946/1077 - Train Accuracy:  0.531, Validation Accuracy:  0.569, Loss:  3.112
# Epoch   5 Batch  947/1077 - Train Accuracy:  0.509, Validation Accuracy:  0.567, Loss:  3.153
# Epoch   5 Batch  948/1077 - Train Accuracy:  0.514, Validation Accuracy:  0.567, Loss:  3.050
# Epoch   5 Batch  949/1077 - Train Accuracy:  0.588, Validation Accuracy:  0.565, Loss:  3.051
# Epoch   5 Batch  950/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.565, Loss:  3.068
# Epoch   5 Batch  951/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.565, Loss:  3.141
# Epoch   5 Batch  952/1077 - Train Accuracy:  0.531, Validation Accuracy:  0.561, Loss:  3.182
# Epoch   5 Batch  953/1077 - Train Accuracy:  0.545, Validation Accuracy:  0.561, Loss:  3.124
# Epoch   5 Batch  954/1077 - Train Accuracy:  0.498, Validation Accuracy:  0.561, Loss:  3.120
# Epoch   5 Batch  955/1077 - Train Accuracy:  0.541, Validation Accuracy:  0.560, Loss:  3.094
# Epoch   5 Batch  956/1077 - Train Accuracy:  0.567, Validation Accuracy:  0.557, Loss:  3.138
# Epoch   5 Batch  957/1077 - Train Accuracy:  0.575, Validation Accuracy:  0.557, Loss:  3.012
# Epoch   5 Batch  958/1077 - Train Accuracy:  0.552, Validation Accuracy:  0.557, Loss:  3.096
# Epoch   5 Batch  959/1077 - Train Accuracy:  0.565, Validation Accuracy:  0.557, Loss:  3.104
# Epoch   5 Batch  960/1077 - Train Accuracy:  0.566, Validation Accuracy:  0.560, Loss:  3.119
# Epoch   5 Batch  961/1077 - Train Accuracy:  0.523, Validation Accuracy:  0.560, Loss:  3.128
# Epoch   5 Batch  962/1077 - Train Accuracy:  0.578, Validation Accuracy:  0.557, Loss:  3.122
# Epoch   5 Batch  963/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.559, Loss:  3.179
# Epoch   5 Batch  964/1077 - Train Accuracy:  0.548, Validation Accuracy:  0.556, Loss:  3.237
# Epoch   5 Batch  965/1077 - Train Accuracy:  0.495, Validation Accuracy:  0.560, Loss:  3.102
# Epoch   5 Batch  966/1077 - Train Accuracy:  0.597, Validation Accuracy:  0.560, Loss:  3.105
# Epoch   5 Batch  967/1077 - Train Accuracy:  0.558, Validation Accuracy:  0.559, Loss:  3.114
# Epoch   5 Batch  968/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.559, Loss:  3.205
# Epoch   5 Batch  969/1077 - Train Accuracy:  0.574, Validation Accuracy:  0.559, Loss:  3.072
# Epoch   5 Batch  970/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.558, Loss:  3.104
# Epoch   5 Batch  971/1077 - Train Accuracy:  0.557, Validation Accuracy:  0.557, Loss:  3.073
# Epoch   5 Batch  972/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.558, Loss:  3.139
# Epoch   5 Batch  973/1077 - Train Accuracy:  0.584, Validation Accuracy:  0.560, Loss:  3.058
# Epoch   5 Batch  974/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.559, Loss:  3.153
# Epoch   5 Batch  975/1077 - Train Accuracy:  0.566, Validation Accuracy:  0.562, Loss:  3.090
# Epoch   5 Batch  976/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.561, Loss:  3.109
# Epoch   5 Batch  977/1077 - Train Accuracy:  0.552, Validation Accuracy:  0.561, Loss:  3.130
# Epoch   5 Batch  978/1077 - Train Accuracy:  0.568, Validation Accuracy:  0.561, Loss:  3.073
# Epoch   5 Batch  979/1077 - Train Accuracy:  0.521, Validation Accuracy:  0.561, Loss:  3.206
# Epoch   5 Batch  980/1077 - Train Accuracy:  0.563, Validation Accuracy:  0.561, Loss:  3.154
# Epoch   5 Batch  981/1077 - Train Accuracy:  0.512, Validation Accuracy:  0.561, Loss:  3.159
# Epoch   5 Batch  982/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.556, Loss:  3.103
# Epoch   5 Batch  983/1077 - Train Accuracy:  0.531, Validation Accuracy:  0.555, Loss:  3.116
# Epoch   5 Batch  984/1077 - Train Accuracy:  0.508, Validation Accuracy:  0.555, Loss:  3.116
# Epoch   5 Batch  985/1077 - Train Accuracy:  0.578, Validation Accuracy:  0.554, Loss:  3.191
# Epoch   5 Batch  986/1077 - Train Accuracy:  0.515, Validation Accuracy:  0.554, Loss:  3.046
# Epoch   5 Batch  987/1077 - Train Accuracy:  0.546, Validation Accuracy:  0.554, Loss:  3.093
# Epoch   5 Batch  988/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.554, Loss:  3.146
# Epoch   5 Batch  989/1077 - Train Accuracy:  0.550, Validation Accuracy:  0.558, Loss:  3.142
# Epoch   5 Batch  990/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.558, Loss:  3.197
# Epoch   5 Batch  991/1077 - Train Accuracy:  0.552, Validation Accuracy:  0.558, Loss:  3.121
# Epoch   5 Batch  992/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.558, Loss:  3.137
# Epoch   5 Batch  993/1077 - Train Accuracy:  0.582, Validation Accuracy:  0.558, Loss:  3.062
# Epoch   5 Batch  994/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.559, Loss:  3.201
# Epoch   5 Batch  995/1077 - Train Accuracy:  0.555, Validation Accuracy:  0.559, Loss:  3.105
# Epoch   5 Batch  996/1077 - Train Accuracy:  0.539, Validation Accuracy:  0.560, Loss:  3.125
# Epoch   5 Batch  997/1077 - Train Accuracy:  0.517, Validation Accuracy:  0.560, Loss:  3.116
# Epoch   5 Batch  998/1077 - Train Accuracy:  0.491, Validation Accuracy:  0.560, Loss:  3.091
# Epoch   5 Batch  999/1077 - Train Accuracy:  0.560, Validation Accuracy:  0.565, Loss:  3.122
# Epoch   5 Batch 1000/1077 - Train Accuracy:  0.586, Validation Accuracy:  0.564, Loss:  3.076
# Epoch   5 Batch 1001/1077 - Train Accuracy:  0.558, Validation Accuracy:  0.562, Loss:  3.055
# Epoch   5 Batch 1002/1077 - Train Accuracy:  0.552, Validation Accuracy:  0.565, Loss:  3.129
# Epoch   5 Batch 1003/1077 - Train Accuracy:  0.558, Validation Accuracy:  0.565, Loss:  3.109
# Epoch   5 Batch 1004/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.566, Loss:  3.124
# Epoch   5 Batch 1005/1077 - Train Accuracy:  0.533, Validation Accuracy:  0.570, Loss:  3.095
# Epoch   5 Batch 1006/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.570, Loss:  3.088
# Epoch   5 Batch 1007/1077 - Train Accuracy:  0.570, Validation Accuracy:  0.568, Loss:  3.162
# Epoch   5 Batch 1008/1077 - Train Accuracy:  0.547, Validation Accuracy:  0.570, Loss:  3.134
# Epoch   5 Batch 1009/1077 - Train Accuracy:  0.549, Validation Accuracy:  0.568, Loss:  3.029
# Epoch   5 Batch 1010/1077 - Train Accuracy:  0.546, Validation Accuracy:  0.567, Loss:  3.188
# Epoch   5 Batch 1011/1077 - Train Accuracy:  0.541, Validation Accuracy:  0.567, Loss:  3.088
# Epoch   5 Batch 1012/1077 - Train Accuracy:  0.521, Validation Accuracy:  0.566, Loss:  3.106
# Epoch   5 Batch 1013/1077 - Train Accuracy:  0.539, Validation Accuracy:  0.560, Loss:  3.116
# Epoch   5 Batch 1014/1077 - Train Accuracy:  0.529, Validation Accuracy:  0.561, Loss:  3.117
# Epoch   5 Batch 1015/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.553, Loss:  3.173
# Epoch   5 Batch 1016/1077 - Train Accuracy:  0.511, Validation Accuracy:  0.552, Loss:  3.070
# Epoch   5 Batch 1017/1077 - Train Accuracy:  0.572, Validation Accuracy:  0.556, Loss:  3.200
# Epoch   5 Batch 1018/1077 - Train Accuracy:  0.557, Validation Accuracy:  0.555, Loss:  3.172
# Epoch   5 Batch 1019/1077 - Train Accuracy:  0.513, Validation Accuracy:  0.555, Loss:  3.111
# Epoch   5 Batch 1020/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.553, Loss:  3.113
# Epoch   5 Batch 1021/1077 - Train Accuracy:  0.548, Validation Accuracy:  0.548, Loss:  3.146
# Epoch   5 Batch 1022/1077 - Train Accuracy:  0.580, Validation Accuracy:  0.549, Loss:  3.095
# Epoch   5 Batch 1023/1077 - Train Accuracy:  0.578, Validation Accuracy:  0.553, Loss:  3.081
# Epoch   5 Batch 1024/1077 - Train Accuracy:  0.531, Validation Accuracy:  0.553, Loss:  3.143
# Epoch   5 Batch 1025/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.553, Loss:  3.100
# Epoch   5 Batch 1026/1077 - Train Accuracy:  0.613, Validation Accuracy:  0.559, Loss:  3.115
# Epoch   5 Batch 1027/1077 - Train Accuracy:  0.510, Validation Accuracy:  0.563, Loss:  3.016
# Epoch   5 Batch 1028/1077 - Train Accuracy:  0.545, Validation Accuracy:  0.567, Loss:  3.152
# Epoch   5 Batch 1029/1077 - Train Accuracy:  0.535, Validation Accuracy:  0.566, Loss:  3.130
# Epoch   5 Batch 1030/1077 - Train Accuracy:  0.555, Validation Accuracy:  0.566, Loss:  3.169
# Epoch   5 Batch 1031/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.564, Loss:  3.191
# Epoch   5 Batch 1032/1077 - Train Accuracy:  0.562, Validation Accuracy:  0.561, Loss:  3.082
# Epoch   5 Batch 1033/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.559, Loss:  3.160
# Epoch   5 Batch 1034/1077 - Train Accuracy:  0.498, Validation Accuracy:  0.559, Loss:  3.169
# Epoch   5 Batch 1035/1077 - Train Accuracy:  0.564, Validation Accuracy:  0.557, Loss:  3.164
# Epoch   5 Batch 1036/1077 - Train Accuracy:  0.547, Validation Accuracy:  0.558, Loss:  3.172
# Epoch   5 Batch 1037/1077 - Train Accuracy:  0.519, Validation Accuracy:  0.558, Loss:  3.119
# Epoch   5 Batch 1038/1077 - Train Accuracy:  0.528, Validation Accuracy:  0.561, Loss:  3.229
# Epoch   5 Batch 1039/1077 - Train Accuracy:  0.592, Validation Accuracy:  0.562, Loss:  3.101
# Epoch   5 Batch 1040/1077 - Train Accuracy:  0.519, Validation Accuracy:  0.562, Loss:  3.113
# Epoch   5 Batch 1041/1077 - Train Accuracy:  0.528, Validation Accuracy:  0.561, Loss:  3.228
# Epoch   5 Batch 1042/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.560, Loss:  3.239
# Epoch   5 Batch 1043/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.562, Loss:  3.180
# Epoch   5 Batch 1044/1077 - Train Accuracy:  0.544, Validation Accuracy:  0.562, Loss:  3.115
# Epoch   5 Batch 1045/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.559, Loss:  3.155
# Epoch   5 Batch 1046/1077 - Train Accuracy:  0.550, Validation Accuracy:  0.559, Loss:  3.182
# Epoch   5 Batch 1047/1077 - Train Accuracy:  0.560, Validation Accuracy:  0.559, Loss:  3.122
# Epoch   5 Batch 1048/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.561, Loss:  3.093
# Epoch   5 Batch 1049/1077 - Train Accuracy:  0.517, Validation Accuracy:  0.559, Loss:  3.190
# Epoch   5 Batch 1050/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.562, Loss:  3.239
# Epoch   5 Batch 1051/1077 - Train Accuracy:  0.579, Validation Accuracy:  0.560, Loss:  3.175
# Epoch   5 Batch 1052/1077 - Train Accuracy:  0.583, Validation Accuracy:  0.561, Loss:  3.164
# Epoch   5 Batch 1053/1077 - Train Accuracy:  0.568, Validation Accuracy:  0.561, Loss:  3.048
# Epoch   5 Batch 1054/1077 - Train Accuracy:  0.534, Validation Accuracy:  0.558, Loss:  3.133
# Epoch   5 Batch 1055/1077 - Train Accuracy:  0.529, Validation Accuracy:  0.556, Loss:  3.128
# Epoch   5 Batch 1056/1077 - Train Accuracy:  0.554, Validation Accuracy:  0.555, Loss:  3.163
# Epoch   5 Batch 1057/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.556, Loss:  3.182
# Epoch   5 Batch 1058/1077 - Train Accuracy:  0.507, Validation Accuracy:  0.559, Loss:  3.110
# Epoch   5 Batch 1059/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.558, Loss:  3.146
# Epoch   5 Batch 1060/1077 - Train Accuracy:  0.551, Validation Accuracy:  0.560, Loss:  3.136
# Epoch   5 Batch 1061/1077 - Train Accuracy:  0.561, Validation Accuracy:  0.556, Loss:  3.147
# Epoch   5 Batch 1062/1077 - Train Accuracy:  0.521, Validation Accuracy:  0.562, Loss:  3.148
# Epoch   5 Batch 1063/1077 - Train Accuracy:  0.553, Validation Accuracy:  0.562, Loss:  3.184
# Epoch   5 Batch 1064/1077 - Train Accuracy:  0.558, Validation Accuracy:  0.568, Loss:  3.096
# Epoch   5 Batch 1065/1077 - Train Accuracy:  0.499, Validation Accuracy:  0.568, Loss:  3.021
# Epoch   5 Batch 1066/1077 - Train Accuracy:  0.514, Validation Accuracy:  0.568, Loss:  3.052
# Epoch   5 Batch 1067/1077 - Train Accuracy:  0.549, Validation Accuracy:  0.575, Loss:  3.048
# Epoch   5 Batch 1068/1077 - Train Accuracy:  0.539, Validation Accuracy:  0.575, Loss:  3.023
# Epoch   5 Batch 1069/1077 - Train Accuracy:  0.579, Validation Accuracy:  0.574, Loss:  3.062
# Epoch   5 Batch 1070/1077 - Train Accuracy:  0.512, Validation Accuracy:  0.574, Loss:  3.221
# Epoch   5 Batch 1071/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.573, Loss:  3.073
# Epoch   5 Batch 1072/1077 - Train Accuracy:  0.556, Validation Accuracy:  0.569, Loss:  3.153
# Epoch   5 Batch 1073/1077 - Train Accuracy:  0.548, Validation Accuracy:  0.568, Loss:  3.123
# Epoch   5 Batch 1074/1077 - Train Accuracy:  0.560, Validation Accuracy:  0.567, Loss:  3.223
# Epoch   5 Batch 1075/1077 - Train Accuracy:  0.524, Validation Accuracy:  0.565, Loss:  3.191
# Epoch   6 Batch    0/1077 - Train Accuracy:  0.557, Validation Accuracy:  0.562, Loss:  3.027
# Epoch   6 Batch    1/1077 - Train Accuracy:  0.529, Validation Accuracy:  0.559, Loss:  3.179
# Epoch   6 Batch    2/1077 - Train Accuracy:  0.498, Validation Accuracy:  0.556, Loss:  3.194
# Epoch   6 Batch    3/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.555, Loss:  3.209
# Epoch   6 Batch    4/1077 - Train Accuracy:  0.545, Validation Accuracy:  0.551, Loss:  3.176

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
